# %% [markdown]
# ## Build email extractor

# %%
from pydantic import BaseModel, Field, EmailStr
from typing import Optional, Literal
from pydantic_ai import Agent
from constants import MODEL_LARGE
from dotenv import load_dotenv 

load_dotenv()

class EmailExtractor(BaseModel):
    sender_name: Optional[str]
    sender_email: EmailStr
    issue_category: Literal["billing", "damaged product", "technical", "other"]
    urgency: Literal["low", "medium", "high"]
    summary: str = Field(description="Summarize the email in 3-4 sentences.")

email_extractor_agent = Agent(MODEL_LARGE, system_prompt="""
    You are customer support agent, your task is to 
    extract relevant information from an email.
""", output_type=EmailExtractor)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\networks.py:965, in import_email_validator()
#     964 try:
# --> 965     import email_validator
#     966 except ImportError as e:
#
# ModuleNotFoundError: No module named 'email_validator'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 9
#       5 from dotenv import load_dotenv
#       6
#       7 load_dotenv()
#       8
# ----> 9 class EmailExtractor(BaseModel):
#      10     sender_name: Optional[str]
#      11     sender_email: EmailStr
#      12     issue_category: Literal["billing", "damaged product", "technical", "other"]
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_model_construction.py:255, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     251     set_model_mocks(cls)
#     252 else:
#     253     # Any operation that requires accessing the field infos instances should be put inside
#     254     # `complete_model_class()`:
# --> 255     complete_model_class(
#     256         cls,
#     257         config_wrapper,
#     258         ns_resolver,
#     259         raise_errors=False,
#     260         create_model_module=_create_model_module,
#     261     )
#     263 if config_wrapper.frozen and '__hash__' not in namespace:
#     264     set_default_hash_func(cls, bases)
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_model_construction.py:648, in complete_model_class(cls, config_wrapper, ns_resolver, raise_errors, call_on_complete_hook, create_model_module)
#     641 gen_schema = GenerateSchema(
#     642     config_wrapper,
#     643     ns_resolver,
#     644     typevars_map,
#     645 )
#     647 try:
# --> 648     schema = gen_schema.generate_schema(cls)
#     649 except PydanticUndefinedAnnotation as e:
#     650     if raise_errors:
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:729, in GenerateSchema.generate_schema(self, obj)
#     726 schema = self._generate_schema_from_get_schema_method(obj, obj)
#     728 if schema is None:
# --> 729     schema = self._generate_schema_inner(obj)
#     731 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#     732 if metadata_js_function is not None:
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:1023, in GenerateSchema._generate_schema_inner(self, obj)
#    1021 if lenient_issubclass(obj, BaseModel):
#    1022     with self.model_type_stack.push(obj):
# -> 1023         return self._model_schema(obj)
#    1025 if isinstance(obj, PydanticRecursiveRef):
#    1026     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:856, in GenerateSchema._model_schema(self, cls)
#     844     model_schema = core_schema.model_schema(
#     845         cls,
#     846         inner_schema,
#    (...)    852         ref=model_ref,
#     853     )
#     854 else:
#     855     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 856         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     857         computed_fields=[
#     858             self._computed_field_schema(d, decorators.field_serializers)
#     859             for d in computed_fields.values()
#     860         ],
#     861         extras_schema=extras_schema,
#     862         extras_keys_schema=extras_keys_schema,
#     863         model_name=cls.__name__,
#     864     )
#     865     inner_schema = apply_validators(fields_schema, decorators.root_validators.values())
#     866     inner_schema = apply_model_validators(inner_schema, model_validators, 'inner')
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:1228, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1221 def _generate_md_field_schema(
#    1222     self,
#    1223     name: str,
#    1224     field_info: FieldInfo,
#    1225     decorators: DecoratorInfos,
#    1226 ) -> core_schema.ModelField:
#    1227     """Prepare a ModelField to represent a model field."""
# -> 1228     schema, metadata = self._common_field_schema(name, field_info, decorators)
#    1229     return core_schema.model_field(
#    1230         schema,
#    1231         serialization_exclude=field_info.exclude,
#    (...)   1236         metadata=metadata,
#    1237     )
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:1282, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1278         schema = self._apply_annotations(
#    1279             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1280         )
#    1281     else:
# -> 1282         schema = self._apply_annotations(
#    1283             source_type,
#    1284             annotations + validators_from_decorators,
#    1285         )
#    1287 # This V1 compatibility shim should eventually be removed
#    1288 # push down any `each_item=True` validators
#    1289 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1290 # but that's okay because that didn't exist in V1
#    1291 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2227, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema, check_unsupported_field_info_attributes)
#    2219         continue
#    2220     get_inner_schema = self._get_wrapped_inner_schema(
#    2221         get_inner_schema,
#    2222         annotation,
#    2223         pydantic_js_annotation_functions,
#    2224         check_unsupported_field_info_attributes=check_unsupported_field_info_attributes,
#    2225     )
# -> 2227 schema = get_inner_schema(source_type)
#    2228 if pydantic_js_annotation_functions:
#    2229     core_metadata = schema.setdefault('metadata', {})
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     if self._ref_mode == 'to-def':
#      85         ref = schema.get('ref')
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2203, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2202 def inner_handler(obj: Any) -> CoreSchema:
# -> 2203     schema = self._generate_schema_from_get_schema_method(obj, source_type)
#    2205     if schema is None:
#    2206         schema = self._generate_schema_inner(obj)
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:919, in GenerateSchema._generate_schema_from_get_schema_method(self, obj, source)
#     917 else:
#     918     ref_mode = 'to-def'
# --> 919 schema = get_schema(
#     920     source, CallbackGetCoreSchemaHandler(self._generate_schema_inner, self, ref_mode=ref_mode)
#     921 )
#     922 if schema['type'] == 'definitions':
#     923     schema = self.defs.unpack_definitions(schema)
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\networks.py:1005, in EmailStr.__get_pydantic_core_schema__(cls, _source, _handler)
#     999 @classmethod
#    1000 def __get_pydantic_core_schema__(
#    1001     cls,
#    1002     _source: type[Any],
#    1003     _handler: GetCoreSchemaHandler,
#    1004 ) -> core_schema.CoreSchema:
# -> 1005     import_email_validator()
#    1006     return core_schema.no_info_after_validator_function(cls._validate, core_schema.str_schema())
#
# File c:\Users\edvin\Projects\llmops_code_along\.venv\Lib\site-packages\pydantic\networks.py:967, in import_email_validator()
#     965     import email_validator
#     966 except ImportError as e:
# --> 967     raise ImportError("email-validator is not installed, run `pip install 'pydantic[email]'`") from e
#     968 if not version('email-validator').partition('.')[0] == '2':
#     969     raise ImportError('email-validator version >= 2.0 required, run pip install -U email-validator')
#
# ImportError: email-validator is not installed, run `pip install 'pydantic[email]'`

# %% [markdown]
# TODO: load in the data and test the agent on one email

# %%
import pandas as pd

df = pd.read_json("emails_cleaned.json")
df
# Out:
#                                               inputs  \
# 0  {'email': 'From: Erik Lindqvist <erik.lindqvis...
# 1  {'email': 'From: Maja Bergström <maja.bergstro...
# 2  {'email': 'From: Oscar Johansson <oscar.johans...
# 3  {'email': 'From: Linnea Karlsson <linnea.karls...
#
#                                         expectations
# 0  {'expected_response': '{"sender_name": "Erik L...
# 1  {'expected_response': '{"sender_name": "Maja B...
# 2  {'expected_response': '{"sender_name": "Oscar ...
# 3  {'expected_response': '{"sender_name": "Linnea...

# %%
sample_mail = df.iloc[2]["inputs"]["email"]
sample_mail
# Out:
# "From: Oscar Johansson <oscar.johansson@yahoo.se>\nSubject: Cannot access my account for 3 days - Urgent help needed\n\nHello Support Team,\n\nI am reaching out because I have been completely locked out of my account for the past three days and I am running out of ideas on how to fix this on my own. The problem started on Monday evening when I tried to log in as usual but kept receiving an 'Invalid credentials' error despite being absolutely certain that I was entering the correct password.\n\nI followed the instructions on your website to reset my password, but the problem is that the password reset email never arrives in my inbox. I have checked my spam and junk folders multiple times, and there is nothing there either. I have attempted the reset process at least six or seven times across different browsers and even from my phone, but the result is always the same - no email arrives.\n\nThis is causing me real problems because I have important documents and data stored in my account that I urgently need access to for work purposes. I have a deadline coming up this Friday and without access to my account I will not be able to meet it.\n\nI have already tried clearing my browser cache, using incognito mode, and switching from Chrome to Firefox, none of which made any difference. My email address on the account is this one, oscar.johansson@yahoo.se, so I am not sure why the reset emails are not coming through.\n\nPlease help me resolve this as quickly as possible. I am happy to verify my identity in any way necessary.\n\nBest regards,\nOscar Johansson"

# %%
result = await email_extractor_agent.run(sample_mail)
