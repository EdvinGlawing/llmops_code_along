# %% [markdown]
# ## Explore chat in PydanticAI

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv
from constants import MODEL_SMALL, MODEL_MEDIUM, MODEL_LARGE

# overrides eventual caching of environment variables so that we always use env variable from .env
load_dotenv(override=True)

agent = Agent(
    model=MODEL_SMALL,
    system_prompt="Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.",
    retries=1
)

result = await agent.run("Why is it not sunny in göteborg?")

# %%
print(result.output)
# Out:
# Why is it not sunny in Göteborg? 🤔
# Well, it’s because the code just got *cloudy* 🌫️!
#
# Here’s a little programming joke to lighten the mood:
# Why did the programmer bring a umbrella to Python?
# Because they heard it was going to be a *bug* in the weather forecast! 😄
#
# Let me know if you want more code-based humor! 💻😄

# %%
result = await agent.run("what did I just ask you?")
print(result.output)
# Out:
# Oh boy, I see! 🎉 Let's break that down with a chuckle! You just asked me about something—probably because your brain was so busy 😂.
#
# But here's the fun part:
# **Why don't programmers make up their minds?**
# Because they always take too long on `if` statements! 🐍💻
#
# Let me know if you want another bug in your code or a laugh right now! 😄
# (And remember: if you're feeling technical, at least your logic isn’t broken… yet.) 😉

# %% [markdown]
# ## History stored in all_messages

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 9, 16, 22, 52433, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what did I just ask you?', timestamp=datetime.datetime(2026, 4, 13, 9, 16, 22, 52433, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 9, 16, 22, 52433, tzinfo=datetime.timezone.utc), run_id='019d8620-aea4-70cf-9568-e3edf4667338'),
#  ModelResponse(parts=[TextPart(content="Oh boy, I see! 🎉 Let's break that down with a chuckle! You just asked me about something—probably because your brain was so busy 😂. \n\nBut here's the fun part:  \n**Why don't programmers make up their minds?**  \nBecause they always take too long on `if` statements! 🐍💻\n\nLet me know if you want another bug in your code or a laugh right now! 😄  \n(And remember: if you're feeling technical, at least your logic isn’t broken… yet.) 😉")], usage=RequestUsage(input_tokens=49, output_tokens=121, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 9, 16, 23, 221972, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 9, 16, 21, tzinfo=TzInfo(0))}, provider_response_id='gen-1776071781-cWeFEzrlaqOC4yFI2YlU', finish_reason='stop', run_id='019d8620-aea4-70cf-9568-e3edf4667338')]

# %%
result = await agent.run(
    "Give me a cool joke about H2O", message_history=result.all_messages()
)
print(result.output)
# Out:
# Here's a water-themed joke for you:
#
# Why did the water molecule break up with the hydrogen atom?
# Because it was tired of all the *stress* 😄
#
# 💧😂
# Let me know if you want a scientific explanation too! (But probably not...) ✨

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 9, 16, 22, 52433, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what did I just ask you?', timestamp=datetime.datetime(2026, 4, 13, 9, 16, 22, 52433, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 9, 16, 22, 52433, tzinfo=datetime.timezone.utc), run_id='019d8620-aea4-70cf-9568-e3edf4667338'),
#  ModelResponse(parts=[TextPart(content="Oh boy, I see! 🎉 Let's break that down with a chuckle! You just asked me about something—probably because your brain was so busy 😂. \n\nBut here's the fun part:  \n**Why don't programmers make up their minds?**  \nBecause they always take too long on `if` statements! 🐍💻\n\nLet me know if you want another bug in your code or a laugh right now! 😄  \n(And remember: if you're feeling technical, at least your logic isn’t broken… yet.) 😉")], usage=RequestUsage(input_tokens=49, output_tokens=121, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 9, 16, 23, 221972, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 9, 16, 21, tzinfo=TzInfo(0))}, provider_response_id='gen-1776071781-cWeFEzrlaqOC4yFI2YlU', finish_reason='stop', run_id='019d8620-aea4-70cf-9568-e3edf4667338'),
#  ModelRequest(parts=[UserPromptPart(content='Give me a cool joke about H2O', timestamp=datetime.datetime(2026, 4, 13, 9, 17, 50, 560996, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 9, 17, 50, 560996, tzinfo=datetime.timezone.utc), run_id='019d8622-0860-7683-8048-8a38c3fb714b'),
#  ModelResponse(parts=[TextPart(content="Here's a water-themed joke for you:  \n\nWhy did the water molecule break up with the hydrogen atom?  \nBecause it was tired of all the *stress* 😄  \n\n💧😂  \nLet me know if you want a scientific explanation too! (But probably not...) ✨")], usage=RequestUsage(input_tokens=188, output_tokens=66, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 9, 17, 51, 732662, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 9, 17, 49, tzinfo=TzInfo(0))}, provider_response_id='gen-1776071869-mtTTmxVPozDhofSUXMAx', finish_reason='stop', run_id='019d8622-0860-7683-8048-8a38c3fb714b')]
